# %% [markdown]
# <a href="https://colab.research.google.com/github/alifia07nisa/data-science-2026/blob/main/Pertemuan1_Alifia_Choirunnisa_250401020010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Alifia Choirunnisa
#
# NIM : 250401020010
#
# Kelas : IF403

# %% [markdown]
# Output sederhana

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %% [markdown]
# Variabel & tipe data

# %%
nama = "Mahasiswa Informatika"
angkatan = 2025
print(f"Halo, {nama} angkatan {angkatan}!")
# Out:
# Halo, Mahasiswa Informatika angkatan 2025!

# %% [markdown]
# List & perulangan

# %%
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")
# Out:
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub

# %% [markdown]
# Fungsi Python

# %%
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Alifia Choirunnisa","Informatika",2025))
# Out:
# Alifia Choirunnisa | Informatika | 2025

# %% [markdown]
# Pada pertemuan kali ini mempelajari dasar penggunaan python seperti menampilkan teks, menggunakan variabel, membuat list dan perulangan, dan fungsi python.
